# %%
import folium
import requests 
import json 
import matplotlib.cm as cm
import matplotlib.colors as colors
import pandas as pd

from pandas.io.json import json_normalize 
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('toronto_part2.csv')

# %%
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood  Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.81153
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.78564
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.76575
# 3        M1G  Scarborough                                  Woburn  43.76820
# 4        M1H  Scarborough                               Cedarbrae  43.76969
#
#    Longitude
# 0  -79.19552
# 1  -79.15871
# 2  -79.17520
# 3  -79.21761
# 4  -79.23944

# %%
to_drop_unknown = []
geolocator = Nominatim(user_agent="coursera")
for index, row in df.iterrows():
    address = row['Neighborhood'] + ', Toronto'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        #print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df.loc[index, 'Latitude'] = latitude
        df.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)

df.head()
# Out:
# The geograpical coordinate of Malvern, Rouge, Toronto are 43.8091955, -79.2217008.
# Cannot do: Rouge Hill, Port Union, Highland Creek, Toronto, will drop index: 1
# The geograpical coordinate of Guildwood, Morningside, West Hill, Toronto are 43.7534804, -79.1799949.
# The geograpical coordinate of Woburn, Toronto are 43.7598243, -79.2252908.
# The geograpical coordinate of Cedarbrae, Toronto are 43.75646655, -79.22669244258802.
# The geograpical coordinate of Scarborough Village, Toronto are 43.7437422, -79.2116324.
# Cannot do: Kennedy Park, Ionview, East Birchmount Park, Toronto, will drop index: 6
# Cannot do: Golden Mile, Clairlea, Oakridge, Toronto, will drop index: 7
# Cannot do: Cliffside, Cliffcrest, Scarborough Village West, Toronto, will drop index: 8
# Cannot do: Birch Cliff, Cliffside West, Toronto, will drop index: 9
# Cannot do: Dorset Park, Wexford Heights, Scarborough Town Centre, Toronto, will drop index: 10
# The geograpical coordinate of Wexford, Maryvale, Toronto are 43.7612444, -79.296855.
# The geograpical coordinate of Agincourt, Toronto are 43.7853531, -79.2785494.
# Cannot do: Clarks Corners, Tam O'Shanter, Sullivan, Toronto, will drop index: 13
# Cannot do: Milliken, Agincourt North, Steeles East, L'Amoreaux East, Toronto, will drop index: 14
# The geograpical coordinate of Steeles West, L'Amoreaux West, Toronto are 43.7993024, -79.319077.
# The geograpical coordinate of Upper Rouge, Toronto are 43.8049304, -79.1658374.
# The geograpical coordinate of Hillcrest Village, Toronto are 43.6816953, -79.4257118.
# Cannot do: Fairview, Henry Farm, Oriole, Toronto, will drop index: 18
# The geograpical coordinate of Bayview Village, Toronto are 43.7691966, -79.3766617.
# The geograpical coordinate of York Mills, Silver Hills, Toronto are 43.75191235, -79.37364256656159.
# Cannot do: Willowdale, Newtonbrook, Toronto, will drop index: 21
# The geograpical coordinate of Willowdale, Willowdale East, Toronto are 43.7739798, -79.4138331.
# The geograpical coordinate of York Mills West, Toronto are 43.7440391, -79.406657.
# The geograpical coordinate of Willowdale, Willowdale West, Toronto are 43.7739798, -79.4138331.
# The geograpical coordinate of Parkwoods, Toronto are 43.7587999, -79.3201966.
# The geograpical coordinate of Don Mills, Toronto are 43.775347, -79.3459439.
# The geograpical coordinate of Don Mills, Toronto are 43.775347, -79.3459439.
# Cannot do: Bathurst Manor, Wilson Heights, Downsview North, Toronto, will drop index: 28
# Cannot do: Northwood Park, York University, Toronto, will drop index: 29
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Downsview, Toronto are 43.7492988, -79.462248.
# The geograpical coordinate of Victoria Village, Toronto are 43.732658, -79.3111892.
# Cannot do: Parkview Hill, Woodbine Gardens, Toronto, will drop index: 35
# The geograpical coordinate of Woodbine Heights, Toronto are 43.6999302, -79.3191316.
# The geograpical coordinate of The Beaches, Toronto are 43.6710244, -79.296712.
# The geograpical coordinate of Leaside, Toronto are 43.7047983, -79.3680904.
# The geograpical coordinate of Thorncliffe Park, Toronto are 43.704553, -79.3454074.
# Cannot do: East Toronto, Broadview North (Old East York), Toronto, will drop index: 40
# The geograpical coordinate of The Danforth West, Riverdale, Toronto are 43.660364, -79.3425208.
# The geograpical coordinate of India Bazaar, The Beaches West, Toronto are 43.6678854, -79.31062925087636.
# The geograpical coordinate of Studio District, Toronto are 43.64958515, -79.39068322559326.
# The geograpical coordinate of Lawrence Park, Toronto are 43.729199, -79.4032525.
# The geograpical coordinate of Davisville North, Toronto are 43.697936, -79.3972908.
# Cannot do: North Toronto West,  Lawrence Park, Toronto, will drop index: 46
# The geograpical coordinate of Davisville, Toronto are 43.697936, -79.3972908.
# Cannot do: Moore Park, Summerhill East, Toronto, will drop index: 48
# Cannot do: Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Toronto, will drop index: 49
# The geograpical coordinate of Rosedale, Toronto are 43.6783556, -79.3807457.
# Cannot do: St. James Town, Cabbagetown, Toronto, will drop index: 51
# The geograpical coordinate of Church and Wellesley, Toronto are 43.6655242, -79.3838011.
# The geograpical coordinate of Regent Park, Harbourfront, Toronto are 43.64076885, -79.37989177980148.
# Cannot do: Garden District, Ryerson, Toronto, will drop index: 54
# The geograpical coordinate of St. James Town, Toronto are 43.6694032, -79.3727041.
# The geograpical coordinate of Berczy Park, Toronto are 43.64798435, -79.37539591138858.
# The geograpical coordinate of Central Bay Street, Toronto are 43.6561192, -79.38467.
# Cannot do: Richmond, Adelaide, King, Toronto, will drop index: 58
# Cannot do: Harbourfront East, Union Station, Toronto Islands, Toronto, will drop index: 59
# Cannot do: Toronto Dominion Centre, Design Exchange, Toronto, will drop index: 60
# The geograpical coordinate of Commerce Court, Victoria Hotel, Toronto are 43.648163800000006, -79.37776594404383.
# Cannot do: Bedford Park, Lawrence Manor East, Toronto, will drop index: 62
# The geograpical coordinate of Roselawn, Toronto are 43.7105408, -79.4011379.
# Cannot do: Forest Hill North & West, Forest Hill Road Park, Toronto, will drop index: 64
# Cannot do: The Annex, North Midtown, Yorkville, Toronto, will drop index: 65
# The geograpical coordinate of University of Toronto, Harbord, Toronto are 43.6640959, -79.3986695.
# Cannot do: Kensington Market, Chinatown, Grange Park, Toronto, will drop index: 67
# Cannot do: CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport, Toronto, will drop index: 68
# Cannot do: Stn A PO Boxes, Toronto, will drop index: 69
# Cannot do: First Canadian Place, Underground city, Toronto, will drop index: 70
# The geograpical coordinate of Lawrence Manor, Lawrence Heights, Toronto are 43.7152827, -79.4439143.
# The geograpical coordinate of Glencairn, Toronto are 43.7087117, -79.4406853.
# Cannot do: Humewood-Cedarvale, Toronto, will drop index: 73
# Cannot do: Caledonia-Fairbanks, Toronto, will drop index: 74
# The geograpical coordinate of Christie, Toronto are 43.6641106, -79.4184051.
# The geograpical coordinate of Dufferin, Dovercourt Village, Toronto are 43.6602019, -79.4357191.
# Cannot do: Little Portugal, Trinity, Toronto, will drop index: 77
# Cannot do: Brockton, Parkdale Village, Exhibition Place, Toronto, will drop index: 78
# Cannot do: North Park, Maple Leaf Park, Upwood Park, Toronto, will drop index: 79
# Cannot do: Del Ray, Mount Dennis, Keelsdale and Silverthorn, Toronto, will drop index: 80
# The geograpical coordinate of Runnymede, The Junction North, Toronto are 43.6517026, -79.4759978.
# The geograpical coordinate of High Park, The Junction South, Toronto are 43.6538668, -79.4668644.
# The geograpical coordinate of Parkdale, Roncesvalles, Toronto are 43.6412811, -79.4515993.
# The geograpical coordinate of Runnymede, Swansea, Toronto are 43.6517776, -79.4759227.
# Cannot do: Queen's Park, Ontario Provincial Government, Toronto, will drop index: 85
# Cannot do: Canada Post Gateway Processing Centre, Toronto, will drop index: 86
# Cannot do: Business reply mail Processing Centre, South Central Letter Processing Plant Toronto, Toronto, will drop index: 87
# Cannot do: New Toronto, Mimico South, Humber Bay Shores, Toronto, will drop index: 88
# The geograpical coordinate of Alderwood, Long Branch, Toronto are 43.6017173, -79.5452325.
# Cannot do: The Kingsway, Montgomery Road, Old Mill North, Toronto, will drop index: 90
# Cannot do: Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East, Toronto, will drop index: 91
# Cannot do: Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West, Toronto, will drop index: 92
# The geograpical coordinate of Islington Avenue, Humber Valley Village, Toronto are 43.6684992, -79.5339701.
# Cannot do: West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale, Toronto, will drop index: 94
# Cannot do: Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood, Toronto, will drop index: 95
# The geograpical coordinate of Humber Summit, Toronto are 43.7600778, -79.5717598.
# The geograpical coordinate of Humberlea, Emery, Toronto are 43.7397078, -79.5383431.
# The geograpical coordinate of Weston, Toronto are 43.7001608, -79.5162474.
# The geograpical coordinate of Westmount, Toronto are 43.6936399, -79.5210426.
# Cannot do: Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens, Toronto, will drop index: 100
# Cannot do: South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens, Toronto, will drop index: 101
# Cannot do: Northwest, West Humber - Clairville, Toronto, will drop index: 102
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.809196
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.785640
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.753480
# 3        M1G  Scarborough                                  Woburn  43.759824
# 4        M1H  Scarborough                               Cedarbrae  43.756467
#
#    Longitude
# 0 -79.221701
# 1 -79.158710
# 2 -79.179995
# 3 -79.225291
# 4 -79.226692

# %%
clean_df = df.drop(to_drop_unknown)

# %%
clean_df.shape
# Out:
# (56, 5)

# %%
address = 'Toronto'
try:
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
    df.loc[index, 'Latitude'] = latitude
    df.loc[index, 'Longitude'] = longitude
except AttributeError:
    print('Cannot do: {}, will drop index: {}'.format(address, index))

my_map = folium.Map(location=[latitude, longitude], zoom_start=11)


for lat, lng, label in zip(clean_df['Latitude'], clean_df['Longitude'], clean_df['Neighborhood']):
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(my_map)  
    
my_map
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
